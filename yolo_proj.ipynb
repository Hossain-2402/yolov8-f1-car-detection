# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install -q ultralytics
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model.train(
    data = "/content/drive/MyDrive/Colab Notebooks/yolo_proj/data.yaml",
    epochs = 60,
    imgsz = 640,
    batch = 32
)
# Out:
# Ultralytics 8.4.113 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
matrics = model.val()
print(matrics)
# Out:
# Ultralytics 8.4.113 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 334.6±16.2 MB/s, size: 2213.2 KB)
# val: Scanning /content/drive/MyDrive/Colab Notebooks/yolo_proj/valid/labels.cache... 9 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 9/9 2.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.0s/it 2.0s
#                    all          9         16      0.985      0.875      0.925      0.495
#            Alpine A524          8          8      0.999          1      0.995      0.587
#          McLaren MCL40          8          8      0.971       0.75      0.855      0.404
# Speed: 0.4ms preprocess, 7.0ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to /content/runs/detect/val-2
# ...

# %%
best = YOLO("/content/runs/detect/train/weights/best.pt")
best.predict(
    source = "/content/drive/MyDrive/Colab Notebooks/yolo_proj/VID_20260730_164154522.mp4",
    save = True,
    conf = 0.25)
print("\nInference Complete!")
print("Output video:")
print("/content/runs/detect/predict/test.mp4")
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1641) /content/drive/MyDrive/Colab Notebooks/yolo_proj/VID_20260730_164154522.mp4: 384x640 (no detections), 6.6ms
# video 1/1 (frame 2/1641) /content/drive/MyDrive/Colab Notebooks/yolo_proj/VID_20260730_164154522.mp4: 384x640 (no detections), 10.0ms
# video 1/1 (frame 3/1641) /content/drive/MyDrive/Colab Notebooks/yolo_proj/VID_20260730_164154522.mp4: 384x640 (no detections), 9.6ms
# ...

# %%
data_yaml_content = """
train: /content/drive/MyDrive/Colab Notebooks/yolo_proj/train
val: /content/drive/MyDrive/Colab Notebooks/yolo_proj/valid
test: /content/drive/MyDrive/Colab Notebooks/yolo_proj/test

nc: 2

names:
  0: Alpine A524
  1: McLaren MCL40
"""

with open('/content/drive/MyDrive/Colab Notebooks/yolo_proj/data.yaml', 'w') as f:
    f.write(data_yaml_content)

print("Updated data.yaml content:")
with open('/content/drive/MyDrive/Colab Notebooks/yolo_proj/data.yaml', 'r') as f:
    print(f.read())
# Out:
# Updated data.yaml content:
#
# train: /content/drive/MyDrive/Colab Notebooks/yolo_proj/train
# val: /content/drive/MyDrive/Colab Notebooks/yolo_proj/valid
# test: /content/drive/MyDrive/Colab Notebooks/yolo_proj/test
#
# nc: 2
#
# names:
#   0: Alpine A524
#   1: McLaren MCL40
